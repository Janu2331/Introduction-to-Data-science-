# %% [markdown]
# <a href="https://colab.research.google.com/github/Janu2331/Introduction-to-Data-science-/blob/main/Creating_functions_for_Data_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

# %%
#mount use drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#read file from drive
import pandas as pd

# %%
datasetpath = "/content/drive/MyDrive/matches_1930_2022.csv"

# %%
df = pd.read_csv(datasetpath)

# %%
df
# Out:
#          home_team away_team  home_score  home_xg  home_penalty  away_score  \
# 0        Argentina    France           3      3.3           4.0           3
# 1          Croatia   Morocco           2      0.7           NaN           1
# 2           France   Morocco           2      2.0           NaN           0
# 3        Argentina   Croatia           3      2.3           NaN           0
# 4          Morocco  Portugal           1      1.4           NaN           0
# ..             ...       ...         ...      ...           ...         ...
# 959      Argentina    France           1      NaN           NaN           0
# 960     Yugoslavia    Brazil           2      NaN           NaN           1
# 961        Romania      Peru           3      NaN           NaN           1
# 962  United States   Belgium           3      NaN           NaN           0
# 963         France    Mexico           4      NaN           NaN           1
#
# ...

# %%
df.columns
# Out:
# Index(['home_team', 'away_team', 'home_score', 'home_xg', 'home_penalty',
#        'away_score', 'away_xg', 'away_penalty', 'home_manager', 'home_captain',
#        'away_manager', 'away_captain', 'Attendance', 'Venue', 'Officials',
#        'Round', 'Date', 'Score', 'Referee', 'Notes', 'Host', 'Year',
#        'home_goal', 'away_goal', 'home_goal_long', 'away_goal_long',
#        'home_own_goal', 'away_own_goal', 'home_penalty_goal',
#        'away_penalty_goal', 'home_penalty_miss_long', 'away_penalty_miss_long',
#        'home_penalty_shootout_goal_long', 'away_penalty_shootout_goal_long',
#        'home_penalty_shootout_miss_long', 'away_penalty_shootout_miss_long',
#        'home_red_card', 'away_red_card', 'home_yellow_red_card',
#        'away_yellow_red_card', 'home_yellow_card_long',
#        'away_yellow_card_long', 'home_substitute_in_long',
#        'away_substitute_in_long'],
#       dtype='object')

# %%
df['home_team'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 964 entries, 0 to 963
# Series name: home_team
# Non-Null Count  Dtype
# --------------  -----
# 964 non-null    object
# dtypes: object(1)
# memory usage: 7.7+ KB

# %%
df['home_team'].value_counts()
# Out:
# home_team
# Brazil                    85
# Argentina                 59
# Italy                     57
# England                   40
# Germany                   40
#                           ..
# Jamaica                    1
# FR Yugoslavia              1
# Angola                     1
# Trinidad and Tobago        1
# Bosnia and Herzegovina     1
# Name: count, Length: 82, dtype: int64

# %%
df['Date'].value_counts()
# Out:
# Date
# 1958-06-15    8
# 1958-06-08    8
# 1934-05-27    8
# 1958-06-11    7
# 1938-06-05    6
#              ..
# 2006-07-08    1
# 2006-07-05    1
# 2006-07-04    1
# 1966-07-25    1
# 2022-12-18    1
# Name: count, Length: 378, dtype: int64

# %%
df['Score'].value_counts()
# Out:
# Score
# 1–0            118
# 2–1            107
# 1–1             75
# 2–0             71
# 0–0             66
#               ...
# (4) 2–2 (3)      1
# (3) 0–0 (2)      1
# (4) 2–2 (5)      1
# (4) 1–1 (3)      1
# 6–5              1
# Name: count, Length: 71, dtype: int64

# %%
Scoreabovezero = df['Score']>'0-0'

# %%
df[Scoreabovezero]
# Out:
#          home_team away_team  home_score  home_xg  home_penalty  away_score  \
# 1          Croatia   Morocco           2      0.7           NaN           1
# 2           France   Morocco           2      2.0           NaN           0
# 3        Argentina   Croatia           3      2.3           NaN           0
# 4          Morocco  Portugal           1      1.4           NaN           0
# 5          England    France           1      2.4           NaN           2
# ..             ...       ...         ...      ...           ...         ...
# 959      Argentina    France           1      NaN           NaN           0
# 960     Yugoslavia    Brazil           2      NaN           NaN           1
# 961        Romania      Peru           3      NaN           NaN           1
# 962  United States   Belgium           3      NaN           NaN           0
# 963         France    Mexico           4      NaN           NaN           1
#
# ...

# %%
Scorebybrazil = df['home_team'] == 'Brazil'

# %%
df[Scoreabovezero & Scorebybrazil]
# Out:
#     home_team       away_team  home_score  home_xg  home_penalty  away_score  \
# 11     Brazil  Korea Republic           4      3.6           NaN           1
# 34     Brazil     Switzerland           1      1.0           NaN           0
# 51     Brazil          Serbia           2      2.4           NaN           0
# 71     Brazil         Belgium           1      2.8           NaN           2
# 74     Brazil          Mexico           2      2.7           NaN           0
# ..        ...             ...         ...      ...           ...         ...
# 911    Brazil          Sweden           4      NaN           NaN           2
# 915    Brazil  Czechoslovakia           2      NaN           NaN           1
# 917    Brazil  Czechoslovakia           1      NaN           NaN           1
# 926    Brazil          Poland           6      NaN           NaN           5
# 951    Brazil         Bolivia           4      NaN           NaN           0
#
# ...

# %%
brazildf = df[Scoreabovezero & Scorebybrazil].sort_values(by = 'home_score', ascending= True)

# %%
brazildf
# Out:
#     home_team       away_team  home_score  home_xg  home_penalty  away_score  \
# 512    Brazil       Argentina           0      NaN           NaN           1
# 261    Brazil          France           0      NaN           NaN           1
# 695    Brazil          Poland           0      NaN           NaN           1
# 817    Brazil  Czechoslovakia           0      NaN           NaN           0
# 679    Brazil           Spain           0      NaN           NaN           0
# ..        ...             ...         ...      ...           ...         ...
# 887    Brazil          Mexico           5      NaN           NaN           0
# 831    Brazil          France           5      NaN           NaN           2
# 891    Brazil           Spain           6      NaN           NaN           1
# 926    Brazil          Poland           6      NaN           NaN           5
# 893    Brazil          Sweden           7      NaN           NaN           1
#
# ...

# %%
brazildf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 81 entries, 512 to 893
# Data columns (total 44 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   home_team                        81 non-null     object
#  1   away_team                        81 non-null     object
#  2   home_score                       81 non-null     int64
#  3   home_xg                          7 non-null      float64
#  4   home_penalty                     0 non-null      float64
#  5   away_score                       81 non-null     int64
#  6   away_xg                          7 non-null      float64
#  7   away_penalty                     0 non-null      float64
#  8   home_manager                     81 non-null     object
#  9   home_captain                     59 non-null     object
#  10  away_manager                     81 non-null     object
#  11  away_captain                     59 non-null     object
# ...

# %%
# %matplotlib inline

# %%
from matplotlib import pyplot as plt

# %%
brazildf.plot(x ='Year' , y = 'home_score',kind='hexbin')
plt.xlabel('Year')
plt.ylabel('Home score')
plt.title('Brazil Score')
plt.show()

# %%
brazildf.plot(x ='Year' , y = 'home_score',kind='bar')
plt.xlabel('Year')
plt.ylabel('Home score')
plt.title('Brazil Score')
plt.show()

# %%
brazildf.plot(x ='Year' , y = 'home_score',kind='hist')
plt.xlabel('Year')
plt.ylabel('Home score')
plt.title('Brazil Score')
plt.show()

# %%
brazildf.plot(x ='Year' , y = 'home_score',kind='scatter')
plt.xlabel('Year')
plt.ylabel('Home score')
plt.title('Brazil Score')
plt.show()

# %%
df
# Out:
#          home_team away_team  home_score  home_xg  home_penalty  away_score  \
# 0        Argentina    France           3      3.3           4.0           3
# 1          Croatia   Morocco           2      0.7           NaN           1
# 2           France   Morocco           2      2.0           NaN           0
# 3        Argentina   Croatia           3      2.3           NaN           0
# 4          Morocco  Portugal           1      1.4           NaN           0
# ..             ...       ...         ...      ...           ...         ...
# 959      Argentina    France           1      NaN           NaN           0
# 960     Yugoslavia    Brazil           2      NaN           NaN           1
# 961        Romania      Peru           3      NaN           NaN           1
# 962  United States   Belgium           3      NaN           NaN           0
# 963         France    Mexico           4      NaN           NaN           1
#
# ...

# %%
def AnalyzeFrance():
  matchesplayed = df['home_team'].value_counts()['France']
  print(f'total number of matches played by France is : {matchesplayed}')

# %%
AnalyzeFrance()
# Out:
# total number of matches played by France is : 38

# %%
def AnalyzeTowns():
  TownData = df['home_team'].value_counts()
  for _ in TownData.index:
    print(f'toatal  number of matches played by {_} is : {TownData[_]}')

# %%
AnalyzeTowns()
# Out:
# toatal  number of matches played by Brazil is : 85
# toatal  number of matches played by Argentina is : 59
# toatal  number of matches played by Italy is : 57
# toatal  number of matches played by England is : 40
# toatal  number of matches played by Germany is : 40
# toatal  number of matches played by France is : 38
# toatal  number of matches played by West Germany is : 38
# toatal  number of matches played by Spain is : 34
# toatal  number of matches played by Netherlands is : 33
# toatal  number of matches played by Uruguay is : 33
# toatal  number of matches played by Sweden is : 30
# toatal  number of matches played by Belgium is : 23
# toatal  number of matches played by Portugal is : 21
# toatal  number of matches played by Poland is : 20
# toatal  number of matches played by Soviet Union is : 18
# toatal  number of matches played by Hungary is : 18
# toatal  number of matches played by Mexico is : 18
# toatal  number of matches played by Korea Republic is : 18
# ...

# %%
# %matplotlib inline

# %%
Town30 = df['home_team'].value_counts().values > 30

# %%
Town30
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False])

# %%
townName = []
matchesPlayed = []
TownData = df['home_team'].value_counts()
for _ in TownData.index:
  if TownData[_] > 30:
    townName.append(_)
    matchesPlayed.append(TownData[_])

# %%
townName
# Out:
# ['Brazil',
#  'Argentina',
#  'Italy',
#  'England',
#  'Germany',
#  'France',
#  'West Germany',
#  'Spain',
#  'Netherlands',
#  'Uruguay']

# %%
from matplotlib import pyplot as plt

# %%
plt.bar(matchesPlayed,townName)
plt.ylabel('Town Name')
plt.xlabel('Matches Played')
plt.title('Town Name vs Matches Played')
plt.show()

# %%
def matchesPlayedbytown():
  townName = []
  matchesPlayed = []
TownData = df['home_team'].value_counts()
for _ in TownData.index:
  if TownData[_] > 30:
    townName.append(_)
    matchesPlayed.append(TownData[_])
plt.bar(matchesPlayed,townName)
plt.ylabel('Town Name')
plt.xlabel('Matches Played')
plt.title('Town Name vs Matches Played')
plt.show()

# %%
matchesPlayedbytown()

# %%
f1 = df['home_team'].value_counts()

# %%
Above30 = df['home_team'].value_counts()

# %%
filteredData = Above30[Above30> 30]

# %%
filteredData.plot(kind = 'barh')
# Out:
# <Axes: ylabel='home_team'>

# %%
def matchesplayedbyTown2():
  Above30 = df['home_team'].value_counts()
  filteredData = Above30[Above30> 30]
  filteredData.plot(kind = 'barh')

# %%
matchesplayedbyTown2()

# %%
df
# Out:
#          home_team away_team  home_score  home_xg  home_penalty  away_score  \
# 0        Argentina    France           3      3.3           4.0           3
# 1          Croatia   Morocco           2      0.7           NaN           1
# 2           France   Morocco           2      2.0           NaN           0
# 3        Argentina   Croatia           3      2.3           NaN           0
# 4          Morocco  Portugal           1      1.4           NaN           0
# ..             ...       ...         ...      ...           ...         ...
# 959      Argentina    France           1      NaN           NaN           0
# 960     Yugoslavia    Brazil           2      NaN           NaN           1
# 961        Romania      Peru           3      NaN           NaN           1
# 962  United States   Belgium           3      NaN           NaN           0
# 963         France    Mexico           4      NaN           NaN           1
#
# ...

# %%
df['home_team'].value_counts()
# Out:
# home_team
# Brazil                    85
# Argentina                 59
# Italy                     57
# England                   40
# Germany                   40
#                           ..
# Jamaica                    1
# FR Yugoslavia              1
# Angola                     1
# Trinidad and Tobago        1
# Bosnia and Herzegovina     1
# Name: count, Length: 82, dtype: int64

# %%
filteredData = df['home_team'].value_counts()

# %%
f2 = filteredData[filteredData >= 40].index

# %%
f2
# Out:
# Index(['Brazil', 'Argentina', 'Italy', 'England', 'Germany'], dtype='object', name='home_team')

# %%
df2 = df[df["home_team"].isin(f2)]

# %%
df2
# Out:
#      home_team       away_team  home_score  home_xg  home_penalty  away_score  \
# 0    Argentina          France           3      3.3           4.0           3
# 3    Argentina         Croatia           3      2.3           NaN           0
# 5      England          France           1      2.4           NaN           2
# 11      Brazil  Korea Republic           4      3.6           NaN           1
# 13     England         Senegal           3      1.0           NaN           0
# ..         ...             ...         ...      ...           ...         ...
# 948  Argentina   United States           6      NaN           NaN           1
# 949  Argentina           Chile           3      NaN           NaN           1
# 951     Brazil         Bolivia           4      NaN           NaN           0
# 954  Argentina          Mexico           6      NaN           NaN           3
# 959  Argentina          France           1      NaN           NaN           0
#
# ...

# %%
df2["home_xg"].value_counts()
# Out:
# home_xg
# 2.2    2
# 2.4    2
# 1.0    2
# 1.4    2
# 2.8    2
# 2.1    1
# 1.3    1
# 2.6    1
# 0.9    1
# 2.7    1
# 3.3    1
# 2.3    1
# 3.1    1
# 0.8    1
# 0.3    1
# 1.6    1
# 3.6    1
# 1.9    1
# Name: count, dtype: int64

# %%
# %matplotlib inline

# %%
df2.plot(x = 'home_team',y = 'home_xg',kind = 'bar')
# Out:
# <Axes: xlabel='home_team'>

# %%
f3 = df2["home_xg"] > 2.5

# %%
df3 = df2[f3]

# %%
df3
# Out:
#      home_team       away_team  home_score  home_xg  home_penalty  away_score  \
# 0    Argentina          France           3      3.3           4.0           3
# 11      Brazil  Korea Republic           4      3.6           NaN           1
# 53     Germany           Japan           1      3.1           NaN           2
# 71      Brazil         Belgium           1      2.8           NaN           2
# 74      Brazil          Mexico           2      2.7           NaN           0
# 96     England          Panama           6      2.8           NaN           1
# 102     Brazil      Costa Rica           2      2.6           NaN           0
#
#      away_xg  away_penalty      home_manager  home_captain  ...  \
# 0        2.2           2.0    Lionel Scaloni  Lionel Messi  ...
# 11       0.5           NaN              Tite  Thiago Silva  ...
# 53       1.5           NaN       Hansi Flick  Manuel Neuer  ...
# 71       0.5           NaN              Tite       Miranda  ...
# ...

# %%
df3.plot(x="home_team",y="home_xg",kind="bar")
# Out:
# <Axes: xlabel='home_team'>

# %%
from matplotlib import pyplot as plt

# %%
df3.plot(kind= 'bar', x= 'home_team', y= 'home_xg')
plt.xlabel("Home Team")
plt.ylabel("Home XG")
plt.title("Home XG Analysis")
plt.show()

# %%
df3
# Out:
#      home_team       away_team  home_score  home_xg  home_penalty  away_score  \
# 0    Argentina          France           3      3.3           4.0           3
# 11      Brazil  Korea Republic           4      3.6           NaN           1
# 53     Germany           Japan           1      3.1           NaN           2
# 71      Brazil         Belgium           1      2.8           NaN           2
# 74      Brazil          Mexico           2      2.7           NaN           0
# 96     England          Panama           6      2.8           NaN           1
# 102     Brazil      Costa Rica           2      2.6           NaN           0
#
#      away_xg  away_penalty      home_manager  home_captain  ...  \
# 0        2.2           2.0    Lionel Scaloni  Lionel Messi  ...
# 11       0.5           NaN              Tite  Thiago Silva  ...
# 53       1.5           NaN       Hansi Flick  Manuel Neuer  ...
# 71       0.5           NaN              Tite       Miranda  ...
# ...

# %%
df3.plot(x= 'home_team', y= ['home_score','home_xg'], kind= 'bar',color= ['purple','grey'])
plt.xlabel("Home Team")
plt.ylabel("Home XG")
plt.title("Home XG Analysis")
plt.show()

# %%
df4 = df.groupby("home_team")

# %%
df.groupby("home_team")["home_score"]

# %%
df.groupby("home_team")["home_score"].mean()
# Out:
# home_team
# Algeria         0.833333
# Angola          0.000000
# Argentina       2.050847
# Australia       1.000000
# Austria         2.000000
#                   ...
# Uruguay         2.060606
# Wales           0.666667
# West Germany    2.026316
# Yugoslavia      2.562500
# Zaire           0.000000
# Name: home_score, Length: 82, dtype: float64

# %%
df.describe()
# Out:
#        home_score     home_xg  home_penalty  away_score     away_xg  \
# count  964.000000  128.000000     35.000000  964.000000  128.000000
# mean     1.776971    1.435938      3.285714    1.044606    1.192187
# std      1.596676    0.860391      1.226459    1.071233    0.809258
# min      0.000000    0.100000      0.000000    0.000000    0.000000
# 25%      1.000000    0.800000      3.000000    0.000000    0.600000
# 50%      1.000000    1.300000      3.000000    1.000000    1.000000
# 75%      3.000000    1.925000      4.000000    2.000000    1.525000
# max     10.000000    5.200000      5.000000    7.000000    5.700000
#
#        away_penalty     Attendance         Year
# count     35.000000     964.000000   964.000000
# mean       3.057143   45693.374481  1989.244813
# std        1.136115   22704.131689    24.014409
# min        0.000000    2000.000000  1930.000000
# 25%        2.000000   31800.000000  1974.000000
# 50%        3.000000   42725.000000  1994.000000
# ...

# %%
dg = df.groupby("home_team")["home_xg"]

# %%
print(dg.mean())
# Out:
# home_team
# Algeria              NaN
# Angola               NaN
# Argentina       1.842857
# Australia       0.750000
# Austria              NaN
#                   ...
# Uruguay         1.240000
# Wales           0.600000
# West Germany         NaN
# Yugoslavia           NaN
# Zaire                NaN
# Name: home_xg, Length: 82, dtype: float64

# %%
das = pd.DataFrame({
    'Branch':['CSE','BBA','BBA','CSE','ECE'],
    'Name':['One','Two','Three','Four','Five'],
    'Salary':[10000,20000,13000,14000,21000],
})
das
# Out:
#   Branch   Name  Salary
# 0    CSE    One   10000
# 1    BBA    Two   20000
# 2    BBA  Three   13000
# 3    CSE   Four   14000
# 4    ECE   Five   21000

# %%
das
# Out:
#   Branch   Name  Salary
# 0    CSE    One   10000
# 1    BBA    Two   20000
# 2    BBA  Three   13000
# 3    CSE   Four   14000
# 4    ECE   Five   21000

# %%
sv = das.groupby('Branch')['Salary']
print(sv)

# %%
sv.mean()
# Out:
# Branch
# BBA    16500.0
# CSE    12000.0
# ECE    21000.0
# Name: Salary, dtype: float64

# %%
das.describe()
# Out:
#              Salary
# count      5.000000
# mean   15600.000000
# std     4722.287581
# min    10000.000000
# 25%    13000.000000
# 50%    14000.000000
# 75%    20000.000000
# max    21000.000000

# %%
sv1 = das.groupby(['Branch','Name'])['Salary']
sv1

# %%
sv1.mean()
# Out:
# Branch  Name
# BBA     Three    13000.0
#         Two      20000.0
# CSE     Four     14000.0
#         One      10000.0
# ECE     Five     21000.0
# Name: Salary, dtype: float64

# %%
sv1.agg(['mean','min'])
# Out:
#                  mean    min
# Branch Name
# BBA    Three  13000.0  13000
#        Two    20000.0  20000
# CSE    Four   14000.0  14000
#        One    10000.0  10000
# ECE    Five   21000.0  21000

# %%
sv1 = das.groupby(['Branch','Name'])['Salary']

# %%
sv1.max()
# Out:
# Branch  Name
# BBA     Three    13000
#         Two      20000
# CSE     Four     14000
#         One      10000
# ECE     Five     21000
# Name: Salary, dtype: int64

# %%
import random

# %%
age = []
height = []
weight = []

# %%
df
# Out:
#          home_team away_team  home_score  home_xg  home_penalty  away_score  \
# 0        Argentina    France           3      3.3           4.0           3
# 1          Croatia   Morocco           2      0.7           NaN           1
# 2           France   Morocco           2      2.0           NaN           0
# 3        Argentina   Croatia           3      2.3           NaN           0
# 4          Morocco  Portugal           1      1.4           NaN           0
# ..             ...       ...         ...      ...           ...         ...
# 959      Argentina    France           1      NaN           NaN           0
# 960     Yugoslavia    Brazil           2      NaN           NaN           1
# 961        Romania      Peru           3      NaN           NaN           1
# 962  United States   Belgium           3      NaN           NaN           0
# 963         France    Mexico           4      NaN           NaN           1
#
# ...

# %%
df.shape
# Out:
# (964, 44)

# %%
#Loop comprehensions
[age.append(random.randint(18,40)) for _ in range(964)]
print("Age is now having {len(age)}")
# Out:
# Age is now having {len(age)}

# %%
age
# Out:
# [34,
#  19,
#  25,
#  34,
#  31,
#  18,
#  19,
#  20,
#  22,
#  40,
#  23,
#  38,
#  40,
#  20,
#  29,
#  19,
#  18,
#  38,
#  20,
#  27,
#  35,
#  40,
#  19,
#  29,
#  24,
#  34,
#  39,
#  34,
#  31,
#  22,
#  22,
#  32,
#  29,
#  18,
#  36,
#  21,
#  40,
#  40,
#  27,
#  31,
#  39,
#  35,
#  37,
#  28,
#  23,
#  18,
#  34,
#  38,
#  33,
#  21,
#  27,
#  21,
#  36,
#  23,
#  36,
#  18,
#  25,
#  30,
#  33,
#  27,
#  30,
#  19,
#  22,
#  31,
#  29,
#  26,
#  28,
#  29,
#  38,
#  25,
#  35,
#  36,
#  26,
#  25,
#  31,
#  38,
#  26,
#  25,
#  39,
#  22,
#  30,
#  35,
#  32,
#  18,
#  33,
#  31,
#  36,
#  39,
#  37,
#  22,
#  36,
#  20,
#  26,
#  18,
#  39,
#  33,
#  24,
#  39,
#  26,
#  40,
#  40,
#  36,
#  29,
#  34,
#  29,
#  34,
#  21,
#  19,
#  40,
#  31,
#  34,
#  40,
#  22,
#  39,
#  33,
#  37,
#  29,
#  38,
#  30,
#  20,
#  33,
#  30,
#  37,
#  19,
#  38,
#  23,
#  34,
#  23,
#  37,
#  35,
#  39,
#  37,
#  32,
#  20,
#  18,
#  37,
#  19,
#  39,
#  20,
#  29,
#  21,
#  20,
# ...

# %%
#Adding a new column to the DFrame
#Syntax:df['NewcolumnName']=list / Series

# %%
df["YearsofExperience"]=age

# %%
df
# Out:
#          home_team away_team  home_score  home_xg  home_penalty  away_score  \
# 0        Argentina    France           3      3.3           4.0           3
# 1          Croatia   Morocco           2      0.7           NaN           1
# 2           France   Morocco           2      2.0           NaN           0
# 3        Argentina   Croatia           3      2.3           NaN           0
# 4          Morocco  Portugal           1      1.4           NaN           0
# ..             ...       ...         ...      ...           ...         ...
# 959      Argentina    France           1      NaN           NaN           0
# 960     Yugoslavia    Brazil           2      NaN           NaN           1
# 961        Romania      Peru           3      NaN           NaN           1
# 962  United States   Belgium           3      NaN           NaN           0
# 963         France    Mexico           4      NaN           NaN           1
#
# ...

# %%
df['ASP'] = df['YearsofExperience'] - df['home_score']

# %%
df.shape
# Out:
# (964, 46)

# %%
df
# Out:
#          home_team away_team  home_score  home_xg  home_penalty  away_score  \
# 0        Argentina    France           3      3.3           4.0           3
# 1          Croatia   Morocco           2      0.7           NaN           1
# 2           France   Morocco           2      2.0           NaN           0
# 3        Argentina   Croatia           3      2.3           NaN           0
# 4          Morocco  Portugal           1      1.4           NaN           0
# ..             ...       ...         ...      ...           ...         ...
# 959      Argentina    France           1      NaN           NaN           0
# 960     Yugoslavia    Brazil           2      NaN           NaN           1
# 961        Romania      Peru           3      NaN           NaN           1
# 962  United States   Belgium           3      NaN           NaN           0
# 963         France    Mexico           4      NaN           NaN           1
#
# ...

# %%
# %matplotlib inline

# %%
from matplotlib import pyplot as plt

# %%
df.plot(x= 'YearsofExperience', y= ['away_score','home_score'], kind= 'barh', color= ['teal','orange'])
# Out:
# <Axes: ylabel='YearsofExperience'>

# %%
df.plot(x= 'YearsofExperience', y= ['ASP'], kind= 'scatter', color= ['teal'])
# Out:
# <Axes: xlabel='YearsofExperience', ylabel='[ASP]'>

# %%
df['ASP'].plot(kind= 'hist', color= 'teal')
# Out:
# <Axes: ylabel='Frequency'>

# %%
#Function to get graph
def getgraph(DataFrame,column1,column2):
  from matplotlib import pyplot as plt
  #check the length of columns
  if len(DataFrame[column1]) == len(DataFrame[column2]):
    df.plot(x =column1, y=column2, kind= 'bar', color= ['yellow','orange'])
    print ('The graph is successfully created')
  else:
    print('Please check the columns size')

# %%
getgraph(df,'away_score','home_score')
# Out:
# The graph is successfully created
